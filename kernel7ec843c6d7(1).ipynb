# %%
import numpy as np 
import pandas as pd 
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn import metrics
import os
from PIL import Image

RESAMPLE_PER_CLASS_DICT = {0:0, 1:12, 2:5, 3:26, 4:28}

def re_sample(IMAGE_ARR, LABEL, TRAIN_IMAGE_ARRAY, TRAIN_LABEL_ARRAY):
    RANGE = RESAMPLE_PER_CLASS_DICT[LABEL]
    for i in range(RANGE):
        TRAIN_IMAGE_ARRAY.append(IMAGE_ARR)
        TRAIN_LABEL_ARRAY.append(LABEL)
    return TRAIN_IMAGE_ARRAY,TRAIN_LABEL_ARRAY
# Out:
# Using TensorFlow backend.

# %%
images = []
inputLabels = []
count = 0
trainLabels = pd.read_csv('/kaggle/input/diabetic-retinopathy-detection/trainLabels.csv')
label_dict = {}

current_input_train_labels = []
current_input_test_labels = []

current_total_labels = []

input_image_matrix = []
test_image_matrix = []

for i in range(len(trainLabels)):
    label_dict[trainLabels.iloc[i].image] = trainLabels.iloc[i].level
    
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if(filename == 'trainLabels.csv'):
            continue
        imagePath = os.path.join(dirname, filename)
        image = Image.open(imagePath)
        im = image.resize((512, 512))
        arr = keras.preprocessing.image.img_to_array(im)
        current_total_labels.append(label_dict[filename.split('.')[0]])
        if(count <= 800):
            current_input_train_labels.append(label_dict[filename.split('.')[0]])
            input_image_matrix.append(arr)
            inputLabels.append(label_dict[filename.split('.')[0]])      
            input_image_matrix, inputLabels = re_sample(arr, int(label_dict[filename.split('.')[0]]), input_image_matrix, inputLabels)
        else:
            current_input_test_labels.append(label_dict[filename.split('.')[0]])
            test_image_matrix.append(arr)
        count = count + 1

# Any results you write to the current directory are saved as output.

# %%
plt.title("TOTAL DATASET LABEL DISTRIBUTION")
plt.hist(trainLabels.level)
# Out:
# (array([25810.,     0.,  2443.,     0.,     0.,  5292.,     0.,   873.,
#             0.,   708.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.title("CURRENT DATASET LABEL DISTRIBUTION BEFORE RE-SAMPLING")
plt.hist(current_total_labels)
# Out:
# (array([739.,   0.,  59.,   0.,   0., 148.,   0.,  28.,   0.,  26.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.title("CURRENT TRAINING DATASET LABEL DISTRIBUTION AFTER RE-SAMPLING")
plt.hist(inputLabels)
# Out:
# (array([589.,   0., 611.,   0.,   0., 720.,   0., 594.,   0., 667.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.title("CURRENT TEST DATASET LABEL DISTRIBUTION")
plt.hist(current_input_test_labels)
# Out:
# (array([150.,   0.,  12.,   0.,   0.,  28.,   0.,   6.,   0.,   3.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
len(input_image_matrix)
# Out:
# 3181

# %%
train_image_matrix = np.asarray(input_image_matrix[:2000])

# %%
train_image_matrix.shape
# Out:
# (2000, 512, 512, 3)

# %%
one_hot_vector_labels = keras.utils.to_categorical(inputLabels, 5)

# %%
#BASELINE MODEL: LOGISTIC REGRESSION
LR_BASELINE = keras.models.Sequential([
    keras.layers.Flatten(),
    keras.layers.Dense(1, activation='sigmoid'),
    keras.layers.Dense(5, activation='softmax')
])

LR_BASELINE.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

LR_BL_MODEL = LR_BASELINE.fit(train_image_matrix, one_hot_vector_labels[:2000], epochs=20)

LR_BASELINE.summary()
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6123 - accuracy: 0.1870
# Epoch 2/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6076 - accuracy: 0.2185
# Epoch 3/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6067 - accuracy: 0.2100
# Epoch 4/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6060 - accuracy: 0.2070
# Epoch 5/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6056 - accuracy: 0.2175
# Epoch 6/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6052 - accuracy: 0.2175
# Epoch 7/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6050 - accuracy: 0.2175
# Epoch 8/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6049 - accuracy: 0.2175
# Epoch 9/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6047 - accuracy: 0.2175
# Epoch 10/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6047 - accuracy: 0.2175
# Epoch 11/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6046 - accuracy: 0.2175
# Epoch 12/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 1.6046 - accuracy: 0.2175
# Epoch 13/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6045 - accuracy: 0.2175
# Epoch 14/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6045 - accuracy: 0.2175
# Epoch 15/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6045 - accuracy: 0.2175
# Epoch 16/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6044 - accuracy: 0.2175
# Epoch 17/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6044 - accuracy: 0.2025
# Epoch 18/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6044 - accuracy: 0.2175
# Epoch 19/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6044 - accuracy: 0.2100
# Epoch 20/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 1.6044 - accuracy: 0.2175
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 786432)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 786433
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 10
# =================================================================
# Total params: 786,443
# Trainable params: 786,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
accuracy = LR_BL_MODEL.history['accuracy']
loss = LR_BL_MODEL.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='BaseLine accuracy')
plt.title('BaseLine Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, 'b', label='BaseLine loss')
plt.title('BaseLine Loss')
plt.legend()
plt.show()

# %%
model = keras.models.Sequential([
  keras.layers.Conv2D(32, (4, 4), strides=2, activation='relu', input_shape=(512, 512, 3), data_format="channels_last"),
  keras.layers.Conv2D(32, (4, 4), strides=1, activation='relu', input_shape=(255, 255, 32), data_format="channels_last"),  
  keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2, data_format="channels_last"),  
  keras.layers.Conv2D(64, (4, 4), strides=2, activation='relu', input_shape=(127, 127, 32), data_format="channels_last"),
  keras.layers.Conv2D(64, (4, 4), strides=1, activation='relu', input_shape=(62, 62, 64), data_format="channels_last"),  
  keras.layers.MaxPooling2D(pool_size=(3, 3), strides=2, data_format="channels_last"),  
  keras.layers.Conv2D(128, (4, 4), activation='relu', input_shape=(31, 31, 64), data_format="channels_last"),
  keras.layers.Conv2D(128, (4, 4), padding="same", activation='relu', input_shape=(28, 28, 128), data_format="channels_last"),
  keras.layers.Conv2D(128, (4, 4), activation='relu', input_shape=(28, 28, 128), data_format="channels_last"),  
  keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2, data_format="channels_last"),
  keras.layers.Conv2D(64, (2, 2), strides=2, activation='relu', input_shape=(14, 14, 128), data_format="channels_last"),  
  keras.layers.MaxPooling2D(pool_size=(2, 2), data_format="channels_last"),
#   keras.layers.Conv2D(256, (2, 2), padding='same', activation='relu', input_shape=(13, 13, 256), data_format="channels_last"),  
#   keras.layers.MaxPooling2D(pool_size=(2, 2), data_format="channels_last"),  
  #keras.layers.Conv2D(128, (2, 2), padding='same', activation='relu', input_shape=(14, 14, 256), data_format="channels_last"),     
  keras.layers.Flatten(),
  #keras.layers.Dense(2048, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),
  keras.layers.Dense(1024, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),
  #keras.layers.Dense(1025, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),  
  keras.layers.BatchNormalization(epsilon=1e-5, gamma_initializer="uniform"),    
  keras.layers.Dense(512, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),
  keras.layers.Dense(512, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),  
  keras.layers.Dense(128, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),  
  keras.layers.Dense(64, activation='relu', kernel_initializer=keras.initializers.glorot_normal()),  
  keras.layers.Dense(5, activation='softmax', kernel_initializer=keras.initializers.glorot_normal())  
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


model.summary()
#MOD = model.fit_generator(generator=sample_train, epochs=10, steps_per_epoch=1, validation_data=val_train)

MOD = model.fit(train_image_matrix, one_hot_vector_labels[:2000], epochs=50)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 255, 255, 32)      1568
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 252, 252, 32)      16416
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 125, 125, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 61, 61, 64)        32832
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 58, 58, 64)        65600
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 25, 25, 128)       131200
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 25, 25, 128)       262272
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 22, 22, 128)       262272
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 5, 64)          32832
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              263168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 1,933,957
# Trainable params: 1,931,909
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/50
# 2000/2000 [==============================] - 14s 7ms/step - loss: 1.5531 - accuracy: 0.3040
# Epoch 2/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.4788 - accuracy: 0.3720
# Epoch 3/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.4481 - accuracy: 0.3950
# Epoch 4/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.3898 - accuracy: 0.4175
# Epoch 5/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.3356 - accuracy: 0.4355
# Epoch 6/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 1.2653 - accuracy: 0.4705
# Epoch 7/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 1.1528 - accuracy: 0.5265
# Epoch 8/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.1107 - accuracy: 0.5375
# Epoch 9/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 1.0099 - accuracy: 0.5845
# Epoch 10/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.9179 - accuracy: 0.6145
# Epoch 11/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.9045 - accuracy: 0.6215
# Epoch 12/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.8320 - accuracy: 0.6570
# Epoch 13/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.7258 - accuracy: 0.6975
# Epoch 14/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.7727 - accuracy: 0.6800
# Epoch 15/50
# 2000/2000 [==============================] - 13s 7ms/step - loss: 0.6405 - accuracy: 0.7335
# Epoch 16/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.6296 - accuracy: 0.7400
# Epoch 17/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.5709 - accuracy: 0.7685
# Epoch 18/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.5623 - accuracy: 0.7830
# Epoch 19/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.5398 - accuracy: 0.7820
# Epoch 20/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.5065 - accuracy: 0.7790
# Epoch 21/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.4856 - accuracy: 0.7975
# Epoch 22/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.4340 - accuracy: 0.8210
# Epoch 23/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.4794 - accuracy: 0.8040
# Epoch 24/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.4969 - accuracy: 0.8025
# Epoch 25/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 0.3703 - accuracy: 0.8495
# Epoch 26/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.3362 - accuracy: 0.8660
# Epoch 27/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.3533 - accuracy: 0.8620
# Epoch 28/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.4038 - accuracy: 0.8475
# Epoch 29/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.3106 - accuracy: 0.8750
# Epoch 30/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2966 - accuracy: 0.8850
# Epoch 31/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2540 - accuracy: 0.8970
# Epoch 32/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2640 - accuracy: 0.9005
# Epoch 33/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.3449 - accuracy: 0.8660
# Epoch 34/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2329 - accuracy: 0.9075
# Epoch 35/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2594 - accuracy: 0.9055
# Epoch 36/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2205 - accuracy: 0.9130
# Epoch 37/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2072 - accuracy: 0.9265
# Epoch 38/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2353 - accuracy: 0.9115
# Epoch 39/50
# 2000/2000 [==============================] - 13s 7ms/step - loss: 0.2058 - accuracy: 0.9225
# Epoch 40/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.1676 - accuracy: 0.9385
# Epoch 41/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.2015 - accuracy: 0.9260
# Epoch 42/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.1883 - accuracy: 0.9265
# Epoch 43/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 0.1712 - accuracy: 0.9410
# Epoch 44/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 0.1679 - accuracy: 0.9410
# Epoch 45/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 0.1230 - accuracy: 0.9570
# Epoch 46/50
# 2000/2000 [==============================] - 12s 6ms/step - loss: 0.1645 - accuracy: 0.9420
# Epoch 47/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.1638 - accuracy: 0.9425
# Epoch 48/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.1131 - accuracy: 0.9625
# Epoch 49/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.0912 - accuracy: 0.9660
# Epoch 50/50
# 2000/2000 [==============================] - 13s 6ms/step - loss: 0.1218 - accuracy: 0.9565

# %%
accuracy = MOD.history['accuracy']
loss = MOD.history['loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training loss')
plt.title('Training Loss')
plt.legend()
plt.show()

# %%
test_images_ = np.asarray(test_image_matrix)
PREDICT = model.predict_classes(test_images_)
metrics.accuracy_score(PREDICT, current_input_test_labels)
# Out:
# 0.457286432160804
